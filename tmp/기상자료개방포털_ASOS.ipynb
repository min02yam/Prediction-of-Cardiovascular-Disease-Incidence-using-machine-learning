# %% [markdown]
# <a href="https://colab.research.google.com/github/min02yam/wether/blob/main/%EA%B8%B0%EC%83%81%EC%9E%90%EB%A3%8C%EA%B0%9C%EB%B0%A9%ED%8F%AC%ED%84%B8_ASOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 기상자료개방포털> 종관기상관측(ASOS)

# %%
suppressPackageStartupMessages({
  require(dplyr)
  require(magrittr)
  require(stringr)
  require(data.table)
})

# %%
system("gdown --id 1oxm4uyvriYFIHgxdesAs1dciG-5ZAEh9")

# %%
asos=fread("OBS_ASOS_DD_20220729200439.csv")

# %%
fileEncoding = "euc-kr"

# %%
?read.csv

# %%
asos=read.csv("OBS_ASOS_DD_20220729200439.csv", fileEncoding = "euc-kr")

# %%
install.packages("DataExplorer")
library(DataExplorer)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘Rcpp’, ‘htmlwidgets’, ‘igraph’, ‘reshape2’, ‘gridExtra’, ‘networkD3’

# %%
asos %>% head
# Out:
#   지점 지점명 일시       평균기온(°C) 최저기온(°C) 최고기온(°C)
# 1 90   속초   2012-01-01  1.1         -1.5         4.9
# 2 90   속초   2012-01-02 -0.3         -2.9         4.0
# 3 90   속초   2012-01-03 -0.8         -4.2         3.7
# 4 90   속초   2012-01-04 -2.6         -5.6         1.8
# 5 90   속초   2012-01-05 -2.3         -5.8         2.8
# 6 90   속초   2012-01-06 -1.1         -3.8         2.2
#   강수 계속시간(hr) 일강수량(mm) 최대 순간 풍속(m/s) 최대 풍속(m/s) ⋯
# 1 NA                NA            9.8                5.7            ⋯
# 2 NA                NA            6.8                4.6            ⋯
# 3 NA                NA           14.6                8.3            ⋯
# 4 NA                NA           10.0                7.8            ⋯
# 5 NA                NA            7.9                5.1            ⋯
# 6 NA                NA            8.1                5.0            ⋯
#   일 최심신적설(cm) 일 최심적설(cm) 평균 전운량(1/10) 평균 중하층운량(1/10)
# 1 NA                1.6             4.4               4.1
# 2 NA                1.0             3.5               2.5
# 3 NA                 NA             3.3               2.1
# 4 NA                 NA             1.3               1.3
# 5 NA                 NA             0.0               0.0
# 6 NA                 NA             0.9               0.9
#   평균 지면온도(°C) 최저 초상온도(°C) 합계 대형증발량(mm) 합계 소형증발량(mm)
# 1 -1.6               -5.8             NA                  NA
# 2 -1.3               -7.6             NA                  NA
# 3 -2.1               -9.0             NA                  NA
# 4 -3.6               -8.9             NA                  NA
# 5 -4.1               -9.6             NA                  NA
# 6 -3.5              -10.0             NA                  NA
#   기사 안개 계속시간(hr)
# 1      NA
# 2      NA
# 3      NA
# 4      NA
# 5      NA
# 6      NA

# %%
plot_intro(asos)
# Out:
# plot without title

# %%
glimpse(asos)
# Out:
# Rows: 170,372
# Columns: 35
# $ 지점                     <int> 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 9…
# $ 지점명                   <chr> "속초", "속초", "속초", "속초", "속초", "속초…
# $ 일시                     <chr> "2012-01-01", "2012-01-02", "2012-01-03", "20…
# $ 평균기온..C.             <dbl> 1.1, -0.3, -0.8, -2.6, -2.3, -1.1, -0.8, 1.0,…
# $ 최저기온..C.             <dbl> -1.5, -2.9, -4.2, -5.6, -5.8, -3.8, -4.2, -3.…
# $ 최고기온..C.             <dbl> 4.9, 4.0, 3.7, 1.8, 2.8, 2.2, 4.3, 5.3, 6.1, …
# $ 강수.계속시간.hr.        <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ 일강수량.mm.             <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ 최대.순간.풍속.m.s.      <dbl> 9.8, 6.8, 14.6, 10.0, 7.9, 8.1, 4.2, 8.5, 8.8…
# $ 최대.풍속.m.s.           <dbl> 5.7, 4.6, 8.3, 7.8, 5.1, 5.0, 2.7, 5.8, 4.8, …
# $ 최대.풍속.풍향.16방위.   <int> 290, 290, 290, 290, 290, 360, 290, 290, 290, …
# $ 평균.풍속.m.s.           <dbl> 2.2, 2.5, 2.8, 2.4, 2.5, 2.2, 1.9, 1.9, 2.1, …
# $ 최다풍향.16방위.         <int> 290, 290, 290, 290, 290, 290, 290, 290, 290, …
# $ 평균.이슬점온도..C.      <dbl> -9.9, -9.3, -12.5, -16.0, -18.2, -13.5, -11.4…
# $ 최소.상대습도...         <dbl> 26, 39, 26, 23, 17, 28, 31, 13, 26, 16, 21, 1…
# $ 최소.상대습도.시각.hhmi. <int> 1051, 1134, 1223, 1454, 1325, 1136, 1040, 141…
# $ 평균.상대습도...         <dbl> 44.8, 50.9, 41.1, 35.4, 28.9, 38.6, 44.9, 27.…
# $ 평균.증기압.hPa.         <dbl> 2.9, 3.0, 2.4, 1.8, 1.5, 2.2, 2.6, 1.8, 2.6, …
# $ 평균.현지기압.hPa.       <dbl> 1019.3, 1021.4, 1016.3, 1018.5, 1023.0, 1027.…
# $ 최고.해면기압.hPa.       <dbl> 1023.4, 1025.8, 1022.0, 1023.5, 1026.7, 1033.…
# $ 최저.해면기압.hPa.       <dbl> 1018.2, 1021.8, 1015.9, 1016.3, 1023.4, 1026.…
# $ 평균.해면기압.hPa.       <dbl> 1021.6, 1023.7, 1018.6, 1020.8, 1025.3, 1030.…
# $ 가조시간.hr.             <dbl> 9.6, 9.6, 9.6, 9.6, 9.6, 9.6, 9.6, 9.7, 9.7, …
# $ 합계.일조시간.hr.        <dbl> 5.7, 5.8, 6.3, 8.0, 8.8, 8.6, 8.6, 1.2, 7.8, …
# $ 합계.일사량.MJ.m2.       <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ 일.최심신적설.cm.        <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ 일.최심적설.cm.          <dbl> 1.6, 1.0, NA, NA, NA, NA, NA, NA, NA, NA, NA,…
# $ 평균.전운량.1.10.        <dbl> 4.4, 3.5, 3.3, 1.3, 0.0, 0.9, 0.0, 5.3, 0.8, …
# $ 평균.중하층운량.1.10.    <dbl> 4.1, 2.5, 2.1, 1.3, 0.0, 0.9, 0.0, 2.5, 0.0, …
# $ 평균.지면온도..C.        <dbl> -1.6, -1.3, -2.1, -3.6, -4.1, -3.5, -3.1, -2.…
# $ 최저.초상온도..C.        <dbl> -5.8, -7.6, -9.0, -8.9, -9.6, -10.0, -9.4, -8…
# $ 합계.대형증발량.mm.      <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ 합계.소형증발량.mm.      <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ 기사                     <chr> "", "", "", "", "", "", "", "", "{연무}0430-{…
# $ 안개.계속시간.hr.        <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…

# %%
plot_missing(asos)
# Out:
# plot without title

# %%
names(asos)
# Out:
#  [1] "지점"                     "지점명"
#  [3] "일시"                     "평균기온(°C)"
#  [5] "최저기온(°C)"             "최고기온(°C)"
#  [7] "강수 계속시간(hr)"        "일강수량(mm)"
#  [9] "최대 순간 풍속(m/s)"      "최대 풍속(m/s)"
# [11] "최대 풍속 풍향(16방위)"   "평균 풍속(m/s)"
# [13] "최다풍향(16방위)"         "평균 이슬점온도(°C)"
# [15] "최소 상대습도(%)"         "최소 상대습도 시각(hhmi)"
# [17] "평균 상대습도(%)"         "평균 증기압(hPa)"
# [19] "평균 현지기압(hPa)"       "최고 해면기압(hPa)"
# [21] "최저 해면기압(hPa)"       "평균 해면기압(hPa)"
# [23] "가조시간(hr)"             "합계 일조시간(hr)"
# [25] "합계 일사량(MJ/m2)"       "일 최심신적설(cm)"
# [27] "일 최심적설(cm)"          "평균 전운량(1/10)"
# [29] "평균 중하층운량(1/10)"    "평균 지면온도(°C)"
# [31] "최저 초상온도(°C)"        "합계 대형증발량(mm)"
# [33] "합계 소형증발량(mm)"      "기사"
# [35] "안개 계속시간(hr)"

# %%
names(asos) = gsub("\\(.*?\\)","", names(asos))

# %%
asos %>% head
# Out:
#   지점 지점명 일시       평균기온(°C) 최저기온(°C) 최고기온(°C)
# 1 90   속초   2012-01-01  1.1         -1.5         4.9
# 2 90   속초   2012-01-02 -0.3         -2.9         4.0
# 3 90   속초   2012-01-03 -0.8         -4.2         3.7
# 4 90   속초   2012-01-04 -2.6         -5.6         1.8
# 5 90   속초   2012-01-05 -2.3         -5.8         2.8
# 6 90   속초   2012-01-06 -1.1         -3.8         2.2
#   강수 계속시간(hr) 일강수량(mm) 최대 순간 풍속(m/s) 최대 풍속(m/s) ⋯
# 1 NA                NA            9.8                5.7            ⋯
# 2 NA                NA            6.8                4.6            ⋯
# 3 NA                NA           14.6                8.3            ⋯
# 4 NA                NA           10.0                7.8            ⋯
# 5 NA                NA            7.9                5.1            ⋯
# 6 NA                NA            8.1                5.0            ⋯
#   일 최심신적설(cm) 일 최심적설(cm) 평균 전운량(1/10) 평균 중하층운량(1/10)
# 1 NA                1.6             4.4               4.1
# 2 NA                1.0             3.5               2.5
# 3 NA                 NA             3.3               2.1
# 4 NA                 NA             1.3               1.3
# 5 NA                 NA             0.0               0.0
# 6 NA                 NA             0.9               0.9
#   평균 지면온도(°C) 최저 초상온도(°C) 합계 대형증발량(mm) 합계 소형증발량(mm)
# 1 -1.6               -5.8             NA                  NA
# 2 -1.3               -7.6             NA                  NA
# 3 -2.1               -9.0             NA                  NA
# 4 -3.6               -8.9             NA                  NA
# 5 -4.1               -9.6             NA                  NA
# 6 -3.5              -10.0             NA                  NA
#   기사 안개 계속시간(hr)
# 1      NA
# 2      NA
# 3      NA
# 4      NA
# 5      NA
# 6      NA
