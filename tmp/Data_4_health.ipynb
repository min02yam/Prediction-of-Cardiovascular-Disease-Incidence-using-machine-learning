# %% [markdown]
# <a href="https://colab.research.google.com/github/min02yam/wether/blob/main/4_%EA%B1%B4%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [4]. 건강

# %% [markdown]
# # 0.라이브러리 및 데이터 로드

# %%
install.packages("DataExplorer")
library(DataExplorer)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘Rcpp’, ‘htmlwidgets’, ‘igraph’, ‘reshape2’, ‘gridExtra’, ‘networkD3’

# %%
suppressPackageStartupMessages({
  require(tidyverse)
  require(magrittr)
  require(data.table)
})

# %%
system("gdown --id 1kvnZceijsOc9snijAJ8EQvylOGGg0FlF") # 1. 걷기실천율
system("gdown --id 17BRsS_8S_T2RhpVvpNcPPG7ltATg0gWb") # 2. 고혈압진단경험률
system("gdown --id 18xpWFt4-2inWz6HF8EVlb51LiZvr_sic") #3. 당뇨병진단경험률
system("gdown --id 1NyXxYTx92kQmDlLhjvUSMDX7gs8KuO_n") #4. 스트레스 인지율
system("gdown --id 1UJl8M0-9gvIxuR6-6YNflnproVolMHUx") #5. 체중조절 시도율 
system("gdown --id 1OgZkpTkcQNQ0MgDudY_4Bvq705cWu8iC") # 6.월간음주율
system("gdown --id 1MKeyfoUU05A_KVqjVpI43zGHBFGjV94E")  # 7.현재흡연율
system("gdown --id 10bHvaSWUeXsT5X2raNeqGnENZaRKAXHU") # 8. 흡연율

# %%
걷기실천= read.csv("시·군·구별_걷기_실천율_20220730194221.csv", fileEncoding = "euc-kr")
고혈압 = read.csv("시·군·구별_고혈압_진단_경험률_30세_이상__20220730200722.csv", fileEncoding = "euc-kr")
당뇨병 = read.csv("시·군·구별_당뇨병_진단_경험률_30세_이상__20220730201136.csv", fileEncoding = "euc-kr")
스트레스 = read.csv("시·군·구별_스트레스_인지율_20220730194927.csv", fileEncoding = "euc-kr")
체중조절 = read.csv("시·군·구별_연간_체중조절_시도율_20220730194555.csv", fileEncoding = "euc-kr")
월간음주 = read.csv("시·군·구별_걷기_실천율_20220730194221.csv", fileEncoding = "euc-kr")
현재흡연 = read.csv("시·군·구별_현재흡연율_20220730193637.csv", fileEncoding = "euc-kr")
흡연 = read.csv("흡연율_시도_시_군_구__20220730192834.csv", fileEncoding = "euc-kr")

# %%
head(걷기실천율)
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 3 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 3 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 3 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# ...

# %%
#rm(list=ls())
고령인구비율= read.csv ("고령인구비율_시도_시_군_구__20220730191254.csv", fileEncoding = "euc-kr")
성별인구수= read.csv ("행정구역_시군구_별__성별_인구수_20220730183620.csv", fileEncoding = "euc-kr")
